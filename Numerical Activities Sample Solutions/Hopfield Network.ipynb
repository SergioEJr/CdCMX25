# %% [markdown]
# # Hopfield Network

# %%
from hopfield_functions import *

# %%
path = "test_im.png"
img = convert_img(path, 50)
show_img(img)

# %%
c_img = corrupt_img(img, 1)
show_img(c_img)

# %%
w = calculate_w(img)
r_img = recall(c_img, w)
show_img(r_img)
# Out:
# converged in 1 iterations

# %%
snaps = recall_series(2, c_img, w)
# Out:
# converged in 1 iterations

# %% [markdown]
# ## Multiple Pattern Storage
